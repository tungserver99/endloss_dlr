# %%
# %cd /content/drive/Othercomputers/My Computer/Google Drive Offline/PHD/Quantization/Non_uniform_aaai/newsqueeze-rbvtfull
# Out:
# /content/drive/Othercomputers/My Computer/Google Drive Offline/PHD/Quantization/Non_uniform_aaai/newsqueeze-rbvtfull

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.9/58.9 kB 6.2 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 154.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 11.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.8/100.8 kB 12.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.1/91.1 kB 12.6 MB/s eta 0:00:00
# ...
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24934 sha256=a55da51d5e98356b604dce72354e5d4221f8db90eb562643be7403a560a5b518
#   Stored in directory: /root/.cache/pip/wheels/85/9d/af/01feefbe7d55ef5468796f0c68225b6788e85d9d0a281e7a70
# ...
#   Created wheel for sqlitedict: filename=sqlitedict-2.1.0-py3-none-any.whl size=16862 sha256=717a05768b3bf6f1c50ff53d912becc579146167bbeb97c402fed5a1deaa829b
# ...

# %%
# !pip install torch==2.5.1 torchvision==0.20.1 torchaudio==2.5.1 --index-url https://download.pytorch.org/whl/cu124
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu124
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 908.2/908.2 MB 1.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 119.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 95.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 110.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 72.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 148.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 7.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 11.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 42.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 20.1 MB/s eta 0:00:00
# ...

# %%
# !pip install "datasets==3.6.0"

# %%
import os

os.environ["HF_DATASETS_CACHE"] = "/content/drive/MyDrive/cache/datasets"
os.makedirs(os.environ["HF_DATASETS_CACHE"], exist_ok=True)

# %%
# !MODEL=meta-llama/Llama-2-7b-hf REDPAJAMA_SOURCE=cache bash ./scripts/run_llama3_3bit_redpajama_4096_1024_squeeze.sh
# Out:
# [load_env] Loaded /content/drive/Othercomputers/My Computer/Google Drive Offline/PHD/Quantization/Non_uniform_aaai/newsqueeze-rbvtfull/.env
# [load_env] Loaded /content/drive/Othercomputers/My Computer/Google Drive Offline/PHD/Quantization/Non_uniform_aaai/newsqueeze-rbvtfull/.env
# [ensure_squeeze_base] Building base squeeze artifacts
# [09:25:51 | INFO] Running: [Tokens -> Gradients -> Quantize -> Pack]
# [09:25:51 | INFO] Running Any-Precision Quantization on Llama-2-7b-hf with seed precision 3 and parent precision 3 using redpajama for gradient calculation
# [09:25:51 | INFO] HTTP Request: HEAD https://huggingface.co/meta-llama/Llama-2-7b-hf/resolve/main/config.json "HTTP/1.1 200 OK"
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# [09:25:51 | INFO] HTTP Request: HEAD https://huggingface.co/meta-llama/Llama-2-7b-hf/resolve/main/config.json "HTTP/1.1 200 OK"
# ...

# %%
# !MODEL=meta-llama/Llama-2-7b-hf REDPAJAMA_SOURCE=cache RBVT_LAMBDA=1 bash ./scripts/run_llama3_3bit_redpajama_4096_1024_squeeze_rbvt.sh
# Out:
# [load_env] Loaded /content/drive/Othercomputers/My Computer/Google Drive Offline/PHD/Quantization/Non_uniform_aaai/newsqueeze-rbvtfull/.env
# [load_env] Loaded /content/drive/Othercomputers/My Computer/Google Drive Offline/PHD/Quantization/Non_uniform_aaai/newsqueeze-rbvtfull/.env
# [ensure_squeeze_base] Reusing base squeeze artifacts:
#   quantized=./cache/quantized/Llama-2-7b-hf-w3_orig3-redpajama_s1024_blk4096
#   packed=./cache/packed/anyprec-Llama-2-7b-hf-w3_orig3-redpajama_s1024_blk4096
# [load_env] Loaded /content/drive/Othercomputers/My Computer/Google Drive Offline/PHD/Quantization/Non_uniform_aaai/newsqueeze-rbvtfull/.env
# [run_redpajama_postprocess_fast] Auto-selected devices: 0
# [09:59:57 | INFO] Loading model/analyzer: meta-llama/Llama-2-7b-hf
# [09:59:57 | INFO] HTTP Request: HEAD https://huggingface.co/meta-llama/Llama-2-7b-hf/resolve/main/config.json "HTTP/1.1 200 OK"
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# ...

# %%
# !MODEL=meta-llama/Llama-2-7b-hf BITS=4 REDPAJAMA_SOURCE=cache bash ./scripts/run_llama3_3bit_redpajama_4096_1024_squeeze.sh
# Out:
# [load_env] Loaded /content/drive/Othercomputers/My Computer/Google Drive Offline/PHD/Quantization/Non_uniform_aaai/newsqueeze-rbvtfull/.env
# [load_env] Loaded /content/drive/Othercomputers/My Computer/Google Drive Offline/PHD/Quantization/Non_uniform_aaai/newsqueeze-rbvtfull/.env
# [ensure_squeeze_base] Building base squeeze artifacts
# [11:26:35 | INFO] Running: [Tokens -> Gradients -> Quantize -> Pack]
# [11:26:35 | INFO] Running Any-Precision Quantization on Llama-2-7b-hf with seed precision 4 and parent precision 4 using redpajama for gradient calculation
# [11:26:35 | INFO] HTTP Request: HEAD https://huggingface.co/meta-llama/Llama-2-7b-hf/resolve/main/config.json "HTTP/1.1 200 OK"
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# [11:26:36 | INFO] HTTP Request: HEAD https://huggingface.co/meta-llama/Llama-2-7b-hf/resolve/main/config.json "HTTP/1.1 200 OK"
# Loading weights: 100% 291/291 [00:00<00:00, 4470.28it/s]
# ...

# %%
# !MODEL=meta-llama/Llama-2-7b-hf BITS=4 REDPAJAMA_SOURCE=cache RBVT_LAMBDA=1 bash ./scripts/run_llama3_3bit_redpajama_4096_1024_squeeze_rbvt.sh
# Out:
# [load_env] Loaded /content/drive/Othercomputers/My Computer/Google Drive Offline/PHD/Quantization/Non_uniform_aaai/newsqueeze-rbvtfull/.env
# [load_env] Loaded /content/drive/Othercomputers/My Computer/Google Drive Offline/PHD/Quantization/Non_uniform_aaai/newsqueeze-rbvtfull/.env
# [ensure_squeeze_base] Reusing base squeeze artifacts:
#   quantized=./cache/quantized/Llama-2-7b-hf-w4_orig4-redpajama_s1024_blk4096
#   packed=./cache/packed/anyprec-Llama-2-7b-hf-w4_orig4-redpajama_s1024_blk4096
# [load_env] Loaded /content/drive/Othercomputers/My Computer/Google Drive Offline/PHD/Quantization/Non_uniform_aaai/newsqueeze-rbvtfull/.env
# [run_redpajama_postprocess_fast] Auto-selected devices: 0
# [12:00:11 | INFO] Loading model/analyzer: meta-llama/Llama-2-7b-hf
# [12:00:11 | INFO] HTTP Request: HEAD https://huggingface.co/meta-llama/Llama-2-7b-hf/resolve/main/config.json "HTTP/1.1 200 OK"
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# ...
