# %%
# %cd /content/drive/Othercomputers/My Computer/Google Drive Offline/PHD/Quantization/Non_uniform_aaai/endloss_dlr
# Out:
# /content/drive/Othercomputers/My Computer/Google Drive Offline/PHD/Quantization/Non_uniform_aaai/endloss_dlr

# %%
# !pip3 install torch torchvision --index-url https://download.pytorch.org/whl/cu126

# %%
# !pip install -r requirements.txt

# %%
# !sed -n '1,5p' bash/run_llama2_3bit_redpajama_4096_1024_endloss_dlr.sh | cat -v
# Out:
# #!/usr/bin/env bash
# set -euo pipefail
#
# SCRIPT_DIR="$(cd -- "$(dirname -- "${BASH_SOURCE[0]}")" && pwd)"
# REPO_ROOT="$(cd -- "${SCRIPT_DIR}/.." && pwd)"

# %%
# !sed -i 's/\r$//' bash/run_llama2_3bit_redpajama_4096_1024_endloss_dlr.sh
# !sed -i 's/\r$//' bash/ensure_endloss_dlr_base.sh

# %%
# !pip list

# %%
# !bash bash/run_llama2_3bit_redpajama_4096_1024_endloss_dlr.sh
# Out:
# [05:37:05 | INFO] Running: [Tokens -> End-loss Statistics -> Quantize -> Pack]
# [05:37:05 | INFO] Running End-Loss DLR Scalar Quantization on Llama-2-7b-hf with target precision 3 using redpajama for end-loss statistics
# [05:37:05 | INFO] HTTP Request: HEAD https://huggingface.co/meta-llama/Llama-2-7b-hf/resolve/main/config.json "HTTP/1.1 200 OK"
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# [05:37:05 | INFO] HTTP Request: HEAD https://huggingface.co/meta-llama/Llama-2-7b-hf/resolve/main/config.json "HTTP/1.1 200 OK"
# Loading weights: 100% 291/291 [00:00<00:00, 5873.44it/s]
# [05:37:06 | INFO] HTTP Request: HEAD https://huggingface.co/meta-llama/Llama-2-7b-hf/resolve/main/generation_config.json "HTTP/1.1 200 OK"
# [05:37:06 | INFO] HTTP Request: HEAD https://huggingface.co/meta-llama/Llama-2-7b-hf/resolve/main/custom_generate/generate.py "HTTP/1.1 404 Not Found"
# [05:37:06 | INFO] HTTP Request: HEAD https://huggingface.co/meta-llama/Llama-2-7b-hf/resolve/main/config.json "HTTP/1.1 200 OK"
# [05:37:07 | INFO] HTTP Request: HEAD https://huggingface.co/meta-llama/Llama-2-7b-hf/resolve/main/tokenizer_config.json "HTTP/1.1 200 OK"
# [05:37:07 | INFO] HTTP Request: GET https://huggingface.co/api/models/meta-llama/Llama-2-7b-hf/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# [05:37:07 | INFO] HTTP Request: GET https://huggingface.co/api/models/meta-llama/Llama-2-7b-hf/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# [05:37:07 | INFO] Tokens cache path: ./cache/tokens/Llama-2-7b-hf-redpajama_s1024_blk4096.pt
# [05:37:07 | INFO] Statistics cache path: ./cache/gradients/Llama-2-7b-hf-redpajama_s1024_blk4096-r4_og8_fp16_cb1_gnall_lc8_v2_v4.pt
# [05:37:07 | INFO] Temporary NLL cache path: ./cache/gradients/Llama-2-7b-hf-redpajama_s1024_blk4096-cb1_gnall_lc8_v2.nll_tmp.pt
# [05:37:07 | INFO] Legacy statistics cache path: ./cache/gradients/Llama-2-7b-hf-redpajama_s1024_blk4096.pt
# [05:37:07 | INFO] Legacy temporary NLL cache path: ./cache/gradients/Llama-2-7b-hf-redpajama_s1024_blk4096.nll_tmp.pt
# [05:37:07 | INFO] Quantized cache path: ./cache/quantized/Llama-2-7b-hf-w3_orig3-redpajama_s1024_blk4096
# [05:37:07 | INFO] Model output path: ./cache/packed/anyprec-Llama-2-7b-hf-w3_orig3-redpajama_s1024_blk4096
# [05:37:07 | INFO] ------------------- Get tokens -------------------
# [05:37:07 | INFO] Getting tokens for redpajama with sequence length 4096 and 1024 examples
# [05:37:07 | INFO] Loading tokens from ./cache/tokens/Llama-2-7b-hf-redpajama_s1024_blk4096.pt
# [05:37:22 | INFO] Tokens loading complete.
# [05:37:22 | INFO] ------------------- End-loss Statistics -------------------
# [05:37:22 | INFO] Loading cached end-loss statistics from ./cache/gradients/Llama-2-7b-hf-redpajama_s1024_blk4096-r4_og8_fp16_cb1_gnall_lc8_v2_v4.pt
# [05:38:10 | INFO] End-loss statistics complete.
# [05:38:10 | INFO] ------------------- Quantize: End-Loss DLR Scalar -------------------
# [05:38:10 | INFO] Beginning 3-bit End-Loss DLR Scalar Quantization...
# Quantizing layers:   0%|                                                  | 0/32 [00:00<?, ?layer/s][05:38:10 | INFO] Starting layer 1/32
# [05:38:10 | INFO] Layer 0 module self_attn.q_proj: start
# [05:38:18 | INFO] Layer 0 module self_attn.q_proj: complete
# [05:38:18 | INFO] Layer 0 module self_attn.k_proj: start
# [05:38:24 | INFO] Layer 0 module self_attn.k_proj: complete
# [05:38:24 | INFO] Layer 0 module self_attn.v_proj: start
# [05:38:30 | INFO] Layer 0 module self_attn.v_proj: complete
# [05:38:30 | INFO] Layer 0 module self_attn.o_proj: start
# [05:38:37 | INFO] Layer 0 module self_attn.o_proj: complete
# [05:38:37 | INFO] Layer 0 module mlp.gate_proj: start
# [05:38:54 | INFO] Layer 0 module mlp.gate_proj: complete
# [05:38:54 | INFO] Layer 0 module mlp.up_proj: start
# [05:39:11 | INFO] Layer 0 module mlp.up_proj: complete
# [05:39:11 | INFO] Layer 0 module mlp.down_proj: start
# [05:39:18 | INFO] Layer 0 module mlp.down_proj: complete
# [05:39:18 | INFO] Completed layer 1/32 in 67.67s
# Quantizing layers:   3%|#3                                        | 1/32 [01:07<34:57, 67.67s/layer][05:39:18 | INFO] Starting layer 2/32
# [05:39:18 | INFO] Layer 1 module self_attn.q_proj: start
# [05:39:24 | INFO] Layer 1 module self_attn.q_proj: complete
# [05:39:24 | INFO] Layer 1 module self_attn.k_proj: start
# [05:39:30 | INFO] Layer 1 module self_attn.k_proj: complete
# [05:39:30 | INFO] Layer 1 module self_attn.v_proj: start
# [05:39:37 | INFO] Layer 1 module self_attn.v_proj: complete
# [05:39:37 | INFO] Layer 1 module self_attn.o_proj: start
# [05:39:43 | INFO] Layer 1 module self_attn.o_proj: complete
# [05:39:43 | INFO] Layer 1 module mlp.gate_proj: start
# [05:40:00 | INFO] Layer 1 module mlp.gate_proj: complete
# [05:40:00 | INFO] Layer 1 module mlp.up_proj: start
# [05:40:16 | INFO] Layer 1 module mlp.up_proj: complete
# [05:40:16 | INFO] Layer 1 module mlp.down_proj: start
# [05:40:22 | INFO] Layer 1 module mlp.down_proj: complete
# [05:40:22 | INFO] Completed layer 2/32 in 64.30s
# Quantizing layers:   6%|##6                                       | 2/32 [02:11<32:50, 65.69s/layer][05:40:22 | INFO] Starting layer 3/32
# [05:40:22 | INFO] Layer 2 module self_attn.q_proj: start
# [05:40:29 | INFO] Layer 2 module self_attn.q_proj: complete
# [05:40:29 | INFO] Layer 2 module self_attn.k_proj: start
# [05:40:35 | INFO] Layer 2 module self_attn.k_proj: complete
# [05:40:35 | INFO] Layer 2 module self_attn.v_proj: start
# [05:40:41 | INFO] Layer 2 module self_attn.v_proj: complete
# [05:40:41 | INFO] Layer 2 module self_attn.o_proj: start
# [05:40:47 | INFO] Layer 2 module self_attn.o_proj: complete
# [05:40:47 | INFO] Layer 2 module mlp.gate_proj: start
# [05:41:04 | INFO] Layer 2 module mlp.gate_proj: complete
# [05:41:04 | INFO] Layer 2 module mlp.up_proj: start
# [05:41:20 | INFO] Layer 2 module mlp.up_proj: complete
# [05:41:20 | INFO] Layer 2 module mlp.down_proj: start
# [05:41:26 | INFO] Layer 2 module mlp.down_proj: complete
# [05:41:26 | INFO] Completed layer 3/32 in 63.82s
# Quantizing layers:   9%|###9                                      | 3/32 [03:15<31:20, 64.84s/layer][05:41:26 | INFO] Starting layer 4/32
# [05:41:26 | INFO] Layer 3 module self_attn.q_proj: start
# [05:41:32 | INFO] Layer 3 module self_attn.q_proj: complete
# [05:41:32 | INFO] Layer 3 module self_attn.k_proj: start
# [05:41:39 | INFO] Layer 3 module self_attn.k_proj: complete
# [05:41:39 | INFO] Layer 3 module self_attn.v_proj: start
# [05:41:45 | INFO] Layer 3 module self_attn.v_proj: complete
# [05:41:45 | INFO] Layer 3 module self_attn.o_proj: start
# [05:41:51 | INFO] Layer 3 module self_attn.o_proj: complete
# [05:41:51 | INFO] Layer 3 module mlp.gate_proj: start
# [05:42:07 | INFO] Layer 3 module mlp.gate_proj: complete
# [05:42:07 | INFO] Layer 3 module mlp.up_proj: start
# [05:42:23 | INFO] Layer 3 module mlp.up_proj: complete
# [05:42:23 | INFO] Layer 3 module mlp.down_proj: start
# [05:42:30 | INFO] Layer 3 module mlp.down_proj: complete
# [05:42:30 | INFO] Completed layer 4/32 in 63.68s
# Quantizing layers:  12%|#####2                                    | 4/32 [04:19<30:02, 64.38s/layer][05:42:30 | INFO] Starting layer 5/32
# [05:42:30 | INFO] Layer 4 module self_attn.q_proj: start
# [05:42:36 | INFO] Layer 4 module self_attn.q_proj: complete
# [05:42:36 | INFO] Layer 4 module self_attn.k_proj: start
# [05:42:42 | INFO] Layer 4 module self_attn.k_proj: complete
# [05:42:42 | INFO] Layer 4 module self_attn.v_proj: start
# [05:42:49 | INFO] Layer 4 module self_attn.v_proj: complete
# [05:42:49 | INFO] Layer 4 module self_attn.o_proj: start
# [05:42:55 | INFO] Layer 4 module self_attn.o_proj: complete
# [05:42:55 | INFO] Layer 4 module mlp.gate_proj: start
# [05:43:11 | INFO] Layer 4 module mlp.gate_proj: complete
# [05:43:11 | INFO] Layer 4 module mlp.up_proj: start
# [05:43:27 | INFO] Layer 4 module mlp.up_proj: complete
# [05:43:27 | INFO] Layer 4 module mlp.down_proj: start
# [05:43:34 | INFO] Layer 4 module mlp.down_proj: complete
# [05:43:34 | INFO] Completed layer 5/32 in 63.88s
# Quantizing layers:  16%|######5                                   | 5/32 [05:23<28:53, 64.20s/layer][05:43:34 | INFO] Starting layer 6/32
# [05:43:34 | INFO] Layer 5 module self_attn.q_proj: start
# [05:43:40 | INFO] Layer 5 module self_attn.q_proj: complete
# [05:43:40 | INFO] Layer 5 module self_attn.k_proj: start
# [05:43:46 | INFO] Layer 5 module self_attn.k_proj: complete
# [05:43:46 | INFO] Layer 5 module self_attn.v_proj: start
# [05:43:52 | INFO] Layer 5 module self_attn.v_proj: complete
# [05:43:52 | INFO] Layer 5 module self_attn.o_proj: start
# [05:43:59 | INFO] Layer 5 module self_attn.o_proj: complete
# [05:43:59 | INFO] Layer 5 module mlp.gate_proj: start
# [05:44:15 | INFO] Layer 5 module mlp.gate_proj: complete
# [05:44:15 | INFO] Layer 5 module mlp.up_proj: start
# [05:44:31 | INFO] Layer 5 module mlp.up_proj: complete
# [05:44:31 | INFO] Layer 5 module mlp.down_proj: start
# [05:44:38 | INFO] Layer 5 module mlp.down_proj: complete
# [05:44:38 | INFO] Completed layer 6/32 in 63.85s
# Quantizing layers:  19%|#######8                                  | 6/32 [06:27<27:46, 64.08s/layer][05:44:38 | INFO] Starting layer 7/32
# [05:44:38 | INFO] Layer 6 module self_attn.q_proj: start
# [05:44:44 | INFO] Layer 6 module self_attn.q_proj: complete
# [05:44:44 | INFO] Layer 6 module self_attn.k_proj: start
# [05:44:50 | INFO] Layer 6 module self_attn.k_proj: complete
# [05:44:50 | INFO] Layer 6 module self_attn.v_proj: start
# [05:44:56 | INFO] Layer 6 module self_attn.v_proj: complete
# [05:44:56 | INFO] Layer 6 module self_attn.o_proj: start
# [05:45:02 | INFO] Layer 6 module self_attn.o_proj: complete
# [05:45:02 | INFO] Layer 6 module mlp.gate_proj: start
# [05:45:19 | INFO] Layer 6 module mlp.gate_proj: complete
# [05:45:19 | INFO] Layer 6 module mlp.up_proj: start
# [05:45:35 | INFO] Layer 6 module mlp.up_proj: complete
# [05:45:35 | INFO] Layer 6 module mlp.down_proj: start
# [05:45:42 | INFO] Layer 6 module mlp.down_proj: complete
# [05:45:42 | INFO] Completed layer 7/32 in 64.06s
# Quantizing layers:  22%|#########1                                | 7/32 [07:31<26:41, 64.07s/layer][05:45:42 | INFO] Starting layer 8/32
# [05:45:42 | INFO] Layer 7 module self_attn.q_proj: start
# [05:45:48 | INFO] Layer 7 module self_attn.q_proj: complete
# [05:45:48 | INFO] Layer 7 module self_attn.k_proj: start
# [05:45:54 | INFO] Layer 7 module self_attn.k_proj: complete
# [05:45:54 | INFO] Layer 7 module self_attn.v_proj: start
