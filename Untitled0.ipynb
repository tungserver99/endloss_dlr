# %%
# %cd /content/drive/Othercomputers/My Computer/Google Drive Offline/PHD/Quantization/Non_uniform_aaai/endloss_dlr
# Out:
# /content/drive/Othercomputers/My Computer/Google Drive Offline/PHD/Quantization/Non_uniform_aaai/endloss_dlr

# %%
# !pip3 install torch torchvision --index-url https://download.pytorch.org/whl/cu126

# %%
# !pip install -r requirements.txt

# %%
# !sed -n '1,5p' bash/run_llama2_3bit_redpajama_4096_1024_endloss_dlr.sh | cat -v
# Out:
# #!/usr/bin/env bash
# set -euo pipefail
#
# SCRIPT_DIR="$(cd -- "$(dirname -- "${BASH_SOURCE[0]}")" && pwd)"
# REPO_ROOT="$(cd -- "${SCRIPT_DIR}/.." && pwd)"

# %%
# !sed -i 's/\r$//' bash/run_llama2_3bit_redpajama_4096_1024_endloss_dlr.sh
# !sed -i 's/\r$//' bash/ensure_endloss_dlr_base.sh

# %%
# !pip list

# %%
# !bash bash/run_llama2_3bit_redpajama_4096_1024_endloss_dlr.sh
# Out:
# [03:30:44 | INFO] Running: [Tokens -> End-loss Statistics -> Quantize -> Pack]
# [03:30:44 | INFO] Running End-Loss DLR Scalar Quantization on Llama-2-7b-hf with target precision 3 using redpajama for end-loss statistics
# [03:30:44 | INFO] HTTP Request: HEAD https://huggingface.co/meta-llama/Llama-2-7b-hf/resolve/main/config.json "HTTP/1.1 200 OK"
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# [03:30:44 | INFO] HTTP Request: HEAD https://huggingface.co/meta-llama/Llama-2-7b-hf/resolve/main/config.json "HTTP/1.1 200 OK"
# Loading weights: 100% 291/291 [00:00<00:00, 5880.09it/s]
# [03:30:45 | INFO] HTTP Request: HEAD https://huggingface.co/meta-llama/Llama-2-7b-hf/resolve/main/generation_config.json "HTTP/1.1 200 OK"
# [03:30:45 | INFO] HTTP Request: HEAD https://huggingface.co/meta-llama/Llama-2-7b-hf/resolve/main/custom_generate/generate.py "HTTP/1.1 404 Not Found"
# ...
