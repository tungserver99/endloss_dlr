# %%
# %cd /content/drive/Othercomputers/My Computer/Google Drive Offline/PHD/Quantization/Non_uniform_aaai/endloss_dlr
# Out:
# /content/drive/Othercomputers/My Computer/Google Drive Offline/PHD/Quantization/Non_uniform_aaai/endloss_dlr

# %%
# !pip3 install torch torchvision --index-url https://download.pytorch.org/whl/cu126

# %%
# !pip install -r requirements.txt

# %%
# !sed -n '1,5p' bash/run_llama2_3bit_redpajama_4096_1024_endloss_dlr.sh | cat -v
# Out:
# #!/usr/bin/env bash
# set -euo pipefail
#
# SCRIPT_DIR="$(cd -- "$(dirname -- "${BASH_SOURCE[0]}")" && pwd)"
# REPO_ROOT="$(cd -- "${SCRIPT_DIR}/.." && pwd)"

# %%
# !sed -i 's/\r$//' bash/run_llama2_3bit_redpajama_4096_1024_endloss_dlr.sh
# !sed -i 's/\r$//' bash/ensure_endloss_dlr_base.sh

# %%
# !pip list

# %%
# !bash bash/run_llama2_3bit_redpajama_4096_1024_endloss_dlr.sh
# Out:
# [05:57:05 | INFO] Running: [Tokens -> End-loss Statistics -> Quantize -> Pack]
# [05:57:05 | INFO] Running End-Loss DLR Scalar Quantization on Llama-2-7b-hf with target precision 3 using redpajama for end-loss statistics
# [05:57:05 | INFO] HTTP Request: HEAD https://huggingface.co/meta-llama/Llama-2-7b-hf/resolve/main/config.json "HTTP/1.1 200 OK"
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# [05:57:05 | INFO] HTTP Request: HEAD https://huggingface.co/meta-llama/Llama-2-7b-hf/resolve/main/config.json "HTTP/1.1 200 OK"
# Loading weights: 100% 291/291 [00:00<00:00, 4549.24it/s]
# [05:57:05 | INFO] HTTP Request: HEAD https://huggingface.co/meta-llama/Llama-2-7b-hf/resolve/main/generation_config.json "HTTP/1.1 200 OK"
# [05:57:06 | INFO] HTTP Request: HEAD https://huggingface.co/meta-llama/Llama-2-7b-hf/resolve/main/custom_generate/generate.py "HTTP/1.1 404 Not Found"
# [05:57:06 | INFO] HTTP Request: HEAD https://huggingface.co/meta-llama/Llama-2-7b-hf/resolve/main/config.json "HTTP/1.1 200 OK"
# [05:57:06 | INFO] HTTP Request: HEAD https://huggingface.co/meta-llama/Llama-2-7b-hf/resolve/main/tokenizer_config.json "HTTP/1.1 200 OK"
# [05:57:06 | INFO] HTTP Request: GET https://huggingface.co/api/models/meta-llama/Llama-2-7b-hf/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# [05:57:06 | INFO] HTTP Request: GET https://huggingface.co/api/models/meta-llama/Llama-2-7b-hf/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# [05:57:06 | INFO] Tokens cache path: ./cache/tokens/Llama-2-7b-hf-redpajama_s1024_blk4096.pt
# [05:57:06 | INFO] Statistics cache path: ./cache/gradients/Llama-2-7b-hf-redpajama_s1024_blk4096-r4_og8_fp16_cb1_gnall_lc8_v2_v4.pt
# [05:57:06 | INFO] Temporary NLL cache path: ./cache/gradients/Llama-2-7b-hf-redpajama_s1024_blk4096-cb1_gnall_lc8_v2.nll_tmp.pt
# [05:57:06 | INFO] Legacy statistics cache path: ./cache/gradients/Llama-2-7b-hf-redpajama_s1024_blk4096.pt
# [05:57:06 | INFO] Legacy temporary NLL cache path: ./cache/gradients/Llama-2-7b-hf-redpajama_s1024_blk4096.nll_tmp.pt
# [05:57:06 | INFO] Quantized cache path: ./cache/quantized/Llama-2-7b-hf-w3_orig3-redpajama_s1024_blk4096
# [05:57:06 | INFO] Model output path: ./cache/packed/anyprec-Llama-2-7b-hf-w3_orig3-redpajama_s1024_blk4096
# [05:57:06 | INFO] ------------------- Get tokens -------------------
# [05:57:06 | INFO] Getting tokens for redpajama with sequence length 4096 and 1024 examples
# [05:57:06 | INFO] Loading tokens from ./cache/tokens/Llama-2-7b-hf-redpajama_s1024_blk4096.pt
# [05:57:06 | INFO] Tokens loading complete.
# [05:57:06 | INFO] ------------------- End-loss Statistics -------------------
# [05:57:06 | INFO] Loading cached end-loss statistics from ./cache/gradients/Llama-2-7b-hf-redpajama_s1024_blk4096-r4_og8_fp16_cb1_gnall_lc8_v2_v4.pt
# [05:57:37 | INFO] End-loss statistics complete.
# [05:57:37 | INFO] ------------------- Quantize: End-Loss DLR Scalar -------------------
# [05:57:37 | INFO] Beginning 3-bit End-Loss DLR Scalar Quantization...
# [06:32:57 | INFO] Quantization complete.
# [06:32:57 | INFO] ------------------- Pack -------------------
# Packing:   0% 0/32 [22:14<?, ?it/s]
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/multiprocessing/pool.py", line 856, in next
#     item = self._items.popleft()
#            ^^^^^^^^^^^^^^^^^^^^^
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/content/drive/Othercomputers/My Computer/Google Drive Offline/PHD/Quantization/Non_uniform_aaai/endloss_dlr/quantize.py", line 60, in <module>
#     args = parser.parse_args()
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/Othercomputers/My Computer/Google Drive Offline/PHD/Quantization/Non_uniform_aaai/endloss_dlr/any_precision/quantization/endloss_main.py", line 297, in any_precision_quantize
#     return
# ^^^^^^^^^^
#   File "/content/drive/Othercomputers/My Computer/Google Drive Offline/PHD/Quantization/Non_uniform_aaai/endloss_dlr/any_precision/quantization/pack.py", line 183, in pack
#     for layer_idx, layer_data in tqdm(pool.imap(_process_layer_data, args_list), total=num_layers, desc="Packing"):
#                                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tqdm/std.py", line 1181, in __iter__
#     for obj in iterable:
#                ^^^^^^^^
#   File "/usr/lib/python3.12/multiprocessing/pool.py", line 861, in next
#     self._cond.wait(timeout)
#   File "/usr/lib/python3.12/threading.py", line 355, in wait
#     waiter.acquire()
# KeyboardInterrupt
